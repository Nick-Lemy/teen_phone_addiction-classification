# %%
# %pip install kagglehub
# Out:
# Requirement already satisfied: kagglehub in ./.venv/lib/python3.14/site-packages (1.0.0)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.14 in ./.venv/lib/python3.14/site-packages (from kagglehub) (0.1.15)
# Requirement already satisfied: packaging in ./.venv/lib/python3.14/site-packages (from kagglehub) (26.0)
# Requirement already satisfied: pyyaml in ./.venv/lib/python3.14/site-packages (from kagglehub) (6.0.3)
# Requirement already satisfied: requests in ./.venv/lib/python3.14/site-packages (from kagglehub) (2.32.5)
# Requirement already satisfied: tqdm in ./.venv/lib/python3.14/site-packages (from kagglehub) (4.67.3)
# Requirement already satisfied: protobuf in ./.venv/lib/python3.14/site-packages (from kagglesdk<1.0,>=0.1.14->kagglehub) (6.33.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.14/site-packages (from requests->kagglehub) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.14/site-packages (from requests->kagglehub) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.14/site-packages (from requests->kagglehub) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.14/site-packages (from requests->kagglehub) (2026.1.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("sumedh1507/teen-phone-addiction")

print("Path to dataset files:", path)
